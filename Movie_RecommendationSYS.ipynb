# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
credits_df=pd.read_csv("/content/drive/MyDrive/ML_RecommendationSystem/credits.csv")
movies_df=pd.read_csv("/content/drive/MyDrive/ML_RecommendationSystem/movies.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
credits_df

# %%
movies_df

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
credits_df

# %%
movies_df

# %%
movies_df.head()

# %%
movies_df.tail()

# %%
movies_df = movies_df.merge(credits_df, on = 'title')

# %%
movies_df.shape
# Out:
# (4808, 23)

# %%
movies_df.head()

# %%
movies_df.info()

# %%
movies_df = movies_df[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies_df.head()

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4808 entries, 0 to 4807
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4808 non-null   int64
#  1   title     4808 non-null   object
#  2   overview  4805 non-null   object
#  3   genres    4808 non-null   object
#  4   keywords  4808 non-null   object
#  5   cast      4808 non-null   object
#  6   crew      4808 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
movies_df.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies_df.dropna(isplace=True)

# %%
movies_df.duplicated().sum()
# Out:
# 0

# %%
movies_df.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast

# %%
def convert(obj):
  L=[]
  for i in ast.literal_eval(obj):
    L.append(i['name'])
  return L

# %%
movies_df['genre'] =movies_df['genres'].apply(convert)
movies_df['genre'] =movies_df['keywords'].apply(convert)
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
def convert3(obj):
  L=[]
  counter = 0
  for i in ast.literal_eval(obj):
    if counter !=3:
      L.append(i['name'])
      counter +=1
    else:
      break
    return L

# %%
movies_df['cast']=movies_df['cast'].apply(convert3)

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
def fetch_director(obj):
  L=[]
  for i in ast.literal_eval(obj):
    if i['job']=='Director':
      L.append(i['name'])
  return L

# %%
movies_df['crew']=movies_df['crew'].apply(fetch_director)

# %%
movies_df['overview'] = movies_df['overview'].astype(str)
movies_df['overview'] = movies_df['overview'].apply(lambda x:x.split())

# %%
movies_df['genres'] = movies_df['genres'].apply(lambda x:x.split())

# %%
movies_df['keywords'] = movies_df['keywords'].apply(lambda x:x.split())

# %%
def clean_cast(x):
    if x is None:
        return []
    else:
        return [i.replace(" ","") for i in x]

movies_df['cast'] = movies_df['cast'].apply(clean_cast)

# %%
movies_df['crew'] = movies_df['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                               genres  \
# 0  [[{"id":, 28,, "name":, "Action"},, {"id":, 12...
# 1  [[{"id":, 12,, "name":, "Adventure"},, {"id":,...
# 2  [[{"id":, 28,, "name":, "Action"},, {"id":, 12...
# 3  [[{"id":, 28,, "name":, "Action"},, {"id":, 80...
# ...

# %%
movies_df['tags']= movies_df['overview']+movies_df['genres']+movies_df['keywords']+movies_df['cast']+movies_df['crew']

# %%
movies_df

# %%
new_df=movies_df[['movie_id','title','tags']]

# %%
new_df['tags']=new_df['tags'].apply(lambda x:' '.join(x))
# Out:
# <ipython-input-76-07ec5ba781bf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x:' '.join(x))

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
new_df['tags'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}] [{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name"
# ...

# %%
new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
# Out:
# <ipython-input-80-242d679aab18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words = 'english')

# %%
cv.fit_transform(new_df['tags']).toarray().shape
# Out:
# (4808, 5000)

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
len(cv.get_feature_names_out())
# Out:
# 5000

# %% [markdown]
# nltk= natural language tool kit is a platform used build python program that work with human language

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
  y=[]
  for i in text.split():
    y.append(ps.stem(i))
  return " ".join(y)

# %%
new_df['tags']=new_df['tags'].apply(stem)
# Out:
# <ipython-input-96-402dd7cb6b10>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(stem)

# %% [markdown]
# Measure Text similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(vectors)
# Out:
# array([[1.        , 0.89199476, 0.77738389, ..., 0.75880212, 0.00626815,
#         0.55403099],
#        [0.89199476, 1.        , 0.7768519 , ..., 0.75642157, 0.        ,
#         0.55091213],
#        [0.77738389, 0.7768519 , 1.        , ..., 0.65806774, 0.        ,
#         0.47952945],
#        ...,
#        [0.75880212, 0.75642157, 0.65806774, ..., 1.        , 0.04003204,
#         0.49065338],
#        [0.00626815, 0.        , 0.        , ..., 0.04003204, 1.        ,
#         0.03928371],
#        [0.55403099, 0.55091213, 0.47952945, ..., 0.49065338, 0.03928371,
#         1.        ]])

# %%
cosine_similarity(vectors).shape
# Out:
# (4808, 4808)

# %%
similarity=cosine_similarity(vectors)

# %%
similarity[0]
# Out:
# array([1.        , 0.89199476, 0.77738389, ..., 0.75880212, 0.00626815,
#        0.55403099])

# %%
similarity[0].shape
# Out:
# (4808,)

# %% [markdown]
# enumareate fun converts a data collection object into enumerate objects

# %%
sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x:x[1])[1:6]
# Out:
# [(1082, 0.9297879128345113),
#  (322, 0.9296685934651605),
#  (2448, 0.9275610176226332),
#  (95, 0.9274392701116343),
#  (2223, 0.9262539180832008)]

# %% [markdown]
# **creating recommend function to check the movie recommendation system**

# %%
def recommend(movie):
  movie_index =new_df[new_df['title']== movie].index[0]
  distances = similarity[movie_index]
  movies_list = sorted(list(enumerate(distances)),reverse= True, key = lambda x:x[1])[1:6]
  for i in movies_list:
    print(new_df.iloc[i[0]].title)

# %%
recommend('Avatar')
# Out:
# Dune
# The Fifth Element
# Southland Tales
# Interstellar
# Everyone Says I Love You

# %%
recommend('Iron Man')
# Out:
# Iron Man 3
# The Incredible Hulk
# Thor
# Fantastic 4: Rise of the Silver Surfer
# Mystery Men

# %%
recommend('Liar Liar')
# Out:
# Everyone Says I Love You
# Southland Tales
# Brooklyn's Finest
# Hard Candy
# 42nd Street

# %%
recommend('Captain America: Civil War')
# Out:
# Iron Man 3
# Thor
# Iron Man
# Captain America: The First Avenger
# Fantastic 4: Rise of the Silver Surfer
